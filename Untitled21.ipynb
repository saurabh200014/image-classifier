# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers , models

# %%
(training_images, training_labels),(testing_images,testing_labels)=datasets.cifar10.load_data()
training_images,testing_images=training_images/255,testing_images/255

class_names=['Plane','Car','Bird','Cat','Deer','Dog','Frog','Horse','Ship','Truck']

for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(training_images[i],cmap=plt.cm.binary)
    plt.xlabel(class_names[training_labels[i][0]])
plt.show()

# %%
training_images=training_images[:20000]
training_labels=training_labels[:20000]
testing_images=testing_images[:4000]
testing_labels=testing_labels[:4000]

# %%
model=models.Sequential()
model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(10,activation='softmax'))
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(training_images,training_labels,epochs=10,validation_data=(testing_images,testing_labels))
# Out:
# Epoch 1/10
# 625/625 [==============================] - 15s 22ms/step - loss: 1.7581 - accuracy: 0.3433 - val_loss: 1.4448 - val_accuracy: 0.4812
# Epoch 2/10
# 625/625 [==============================] - 13s 20ms/step - loss: 1.3896 - accuracy: 0.4978 - val_loss: 1.3023 - val_accuracy: 0.5405
# Epoch 3/10
# 625/625 [==============================] - 13s 20ms/step - loss: 1.2327 - accuracy: 0.5623 - val_loss: 1.2618 - val_accuracy: 0.5428
# Epoch 4/10
# 625/625 [==============================] - 13s 20ms/step - loss: 1.1298 - accuracy: 0.6013 - val_loss: 1.1449 - val_accuracy: 0.5990
# Epoch 5/10
# 625/625 [==============================] - 14s 22ms/step - loss: 1.0473 - accuracy: 0.6284 - val_loss: 1.1266 - val_accuracy: 0.6010
# Epoch 6/10
# 625/625 [==============================] - 14s 22ms/step - loss: 0.9779 - accuracy: 0.6550 - val_loss: 1.0835 - val_accuracy: 0.6245
# Epoch 7/10
# 625/625 [==============================] - 13s 21ms/step - loss: 0.9090 - accuracy: 0.6764 - val_loss: 1.0378 - val_accuracy: 0.6352
# Epoch 8/10
# 625/625 [==============================] - 13s 21ms/step - loss: 0.8493 - accuracy: 0.7012 - val_loss: 1.0708 - val_accuracy: 0.6352
# Epoch 9/10
# 625/625 [==============================] - 13s 21ms/step - loss: 0.8074 - accuracy: 0.7138 - val_loss: 1.0445 - val_accuracy: 0.6415
# Epoch 10/10
# 625/625 [==============================] - 13s 21ms/step - loss: 0.7621 - accuracy: 0.7296 - val_loss: 1.0318 - val_accuracy: 0.6540

# %%
loss,accuracy=model.evaluate(testing_images,testing_labels)
print(f"Loss:{loss}")
print(f"Accuracy:{accuracy}")
model.save('image_classifier.model')
# Out:
# 125/125 [==============================] - 1s 6ms/step - loss: 1.0318 - accuracy: 0.6540
# Loss:1.0317531824111938
# Accuracy:0.6539999842643738
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: image_classifier.model\assets
# INFO:tensorflow:Assets written to: image_classifier.model\assets

# %%
model=models.load_model('image_classifier.model')
img=cv.imread(r'C:\Users\rajen\Desktop\AI-DS3\horse32.jpg')
img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img,cmap=plt.cm.binary)
prediction=model.predict(np.array([img])/255)
index=np.argmax(prediction)
print(f'Prediction is {class_names[index]}')
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Prediction is Horse
